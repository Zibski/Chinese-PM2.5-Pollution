# %%
import os

directory = os.getcwd() + '/input/'
inputs = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".csv"):
        inputs.append(os.path.join(directory, filename))
    else:
        continue

# %%
import pandas as pd
df_Shanghai = pd.read_csv(inputs[0])
df_Beijing = pd.read_csv(inputs[1])
df_Shenyang = pd.read_csv(inputs[2])
df_Chengdu = pd.read_csv(inputs[3])
df_Guangzhou = pd.read_csv(inputs[4])

# %%
df_Shanghai['Date'] = pd.to_datetime(df_Shanghai.year*10000+df_Shanghai.month*100+df_Shanghai.day,format='%Y%m%d')
df_Beijing['Date'] = pd.to_datetime(df_Beijing.year*10000+df_Beijing.month*100+df_Beijing.day,format='%Y%m%d')
df_Shenyang['Date'] = pd.to_datetime(df_Shenyang.year*10000+df_Shenyang.month*100+df_Shenyang.day,format='%Y%m%d')
df_Chengdu['Date'] = pd.to_datetime(df_Chengdu.year*10000+df_Chengdu.month*100+df_Chengdu.day,format='%Y%m%d')
df_Guangzhou['Date'] = pd.to_datetime(df_Guangzhou.year*10000+df_Guangzhou.month*100+df_Guangzhou.day,format='%Y%m%d')

# %%
df_Shanghai.set_index(df_Shanghai['Date'],inplace=True)
df_Beijing.set_index(df_Beijing['Date'],inplace=True)
df_Shenyang.set_index(df_Shenyang['Date'],inplace=True)
df_Chengdu.set_index(df_Chengdu['Date'],inplace=True)
df_Guangzhou.set_index(df_Guangzhou['Date'],inplace=True)

# %%
df_Shanghai = df_Shanghai[['PM_Jingan', 'PM_US Post', 'PM_Xuhui']]
df_Beijing = df_Beijing[['PM_Dongsi', 'PM_Dongsihuan', 'PM_Nongzhanguan', 'PM_US Post']]
df_Shenyang = df_Shenyang[['PM_Taiyuanjie', 'PM_US Post', 'PM_Xiaoheyan']]
df_Chengdu = df_Chengdu[['PM_Caotangsi', 'PM_Shahepu', 'PM_US Post']]
df_Guangzhou = df_Guangzhou[['PM_City Station', 'PM_5th Middle School', 'PM_US Post']]

# %%
Shanghai_min = df_Shanghai.min(axis=1)
Shanghai_mean = df_Shanghai.mean(axis=1)
Shanghai_max = df_Shanghai.max(axis=1)

Beijing_min = df_Beijing.min(axis=1)
Beijing_mean = df_Beijing.mean(axis=1)
Beijing_max = df_Beijing.max(axis=1)

Shenyang_min = df_Shenyang.min(axis=1)
Shenyang_mean = df_Shenyang.mean(axis=1)
Shenyang_max = df_Shenyang.max(axis=1)

Chengdu_min = df_Chengdu.min(axis=1)
Chengdu_mean = df_Chengdu.mean(axis=1)
Chengdu_max = df_Chengdu.max(axis=1)

Guangzhou_min = df_Guangzhou.min(axis=1)
Guangzhou_mean = df_Guangzhou.mean(axis=1)
Guangzhou_max = df_Guangzhou.max(axis=1)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

x = Shanghai_min.index.values
y1 = Shanghai_min.values
y2 = Shanghai_mean.values
y3 = Shanghai_max.values

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


plt.figure(figsize=(16, 10))
matplotlib.rc('font', **font)
plt.title('PM25 in Shanghai trend', fontsize=20)
plt.xticks()
plt.plot(x, y1, color='green', alpha=0.5)
plt.plot(x, y2, color='blue', alpha=0.8) 
plt.plot(x,y3, color='red', alpha=0.5)         
plt.fill_between(x, y1, y3, color='grey', alpha=0.5)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family ['normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

x = Beijing_min.index.values
y1 = Beijing_min.values
y2 = Beijing_mean.values
y3 = Beijing_max.values

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


plt.figure(figsize=(16, 10))
matplotlib.rc('font', **font)
plt.title('PM25 in Beijing trend', fontsize=20)
plt.xticks()
plt.plot(x, y1, color='green', alpha=0.5)
plt.plot(x, y2, color='blue', alpha=0.8) 
plt.plot(x,y3, color='red', alpha=0.5)         
plt.fill_between(x, y1, y3, color='grey', alpha=0.5)
plt.show()
